# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("data/unimelb_training.csv")
data.set_index("Grant.Application.ID",drop=True,inplace=True)
data.index.name=None
# Out:
# D:\Users\greg_\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (90,105,119,120,123,124,132,134,135,138,139,147,149,150,153,154,162,164,165,168,169,177,179,183,184,192,194,198,199,207,209,213,214,224,237,239,244) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data = data.ix[:,:25]

# %%
data.head(2)
# Out:
#    Grant.Status Sponsor.Code Grant.Category.Code  \
# 1             1          NaN                 NaN
# 2             1           2B                 10A
#
#   Contract.Value.Band...see.note.A Start.date  RFCD.Code.1  RFCD.Percentage.1  \
# 1                               A     8/11/05     280199.0              100.0
# 2                               B    11/11/05     280103.0               30.0
#
#    RFCD.Code.2  RFCD.Percentage.2  RFCD.Code.3        ...         SEO.Code.1  \
# 1          0.0                0.0          0.0        ...           700299.0
# 2     280106.0               30.0     280203.0        ...           700103.0
#
#    SEO.Percentage.1  SEO.Code.2  SEO.Percentage.2  SEO.Code.3  \
# 1             100.0         0.0               0.0         0.0
# 2              50.0    700102.0              50.0         0.0
#
#    SEO.Percentage.3  SEO.Code.4  SEO.Percentage.4  SEO.Code.5  \
# 1               0.0         0.0               0.0         0.0
# 2               0.0         0.0               0.0         0.0
#
#    SEO.Percentage.5
# 1               0.0
# 2               0.0
#
# [2 rows x 25 columns]

# %%
# Create dummies for Sponsor.Code
data = pd.concat([data,pd.get_dummies(data["Sponsor.Code"],prefix="Sponsor")],axis=1)
data.drop("Sponsor.Code",axis=1,inplace=True)

# %%
# Create dummies for Grant.Category.Code
data = pd.concat([data,pd.get_dummies(data["Grant.Category.Code"],prefix="Cat")],axis=1)
data.drop("Grant.Category.Code",axis=1,inplace=True)

# %%
# Deal with date

a = pd.to_datetime(data["Start.date"])
year = pd.Series([date.year for date in a],name="year")
month = pd.Series([date.month for date in a],name="month")
day = pd.Series([date.day for date in a],name="day")
data["Start.year"] = year
data["Start.month"] = month
data["Start.day"] = day
data.drop(["Start.date"],axis=1,inplace=True)

# %%
# Create dummies for Contract.Val
data = pd.concat([data,pd.get_dummies(data["Contract.Value.Band...see.note.A"],prefix="Contract")],axis=1)
data.drop("Contract.Value.Band...see.note.A",axis=1,inplace=True)

# %%
# Create dummies for RFCD
sub1 = pd.DataFrame(data.ix[:,1:3])
sub1.rename(columns={"RFCD.Code.1":"RFCD.Code",
                     "RFCD.Percentage.1":"RFCD.Percentage"},inplace=True)

sub2 = pd.DataFrame(data.ix[:,3:5])
sub2.rename(columns={"RFCD.Code.2":"RFCD.Code",
                     "RFCD.Percentage.2":"RFCD.Percentage"},inplace=True)

sub3 = pd.DataFrame(data.ix[:,5:7])
sub3.rename(columns={"RFCD.Code.3":"RFCD.Code",
                     "RFCD.Percentage.3":"RFCD.Percentage"},inplace=True)

sub4 = pd.DataFrame(data.ix[:,7:9])
sub4.rename(columns={"RFCD.Code.4":"RFCD.Code",
                     "RFCD.Percentage.4":"RFCD.Percentage"},inplace=True)

sub5 = pd.DataFrame(data.ix[:,9:11])
sub5.rename(columns={"RFCD.Code.5":"RFCD.Code",
                     "RFCD.Percentage.5":"RFCD.Percentage"},inplace=True)

RFCD = sub1.append(sub2,ignore_index=False)
RFCD = RFCD.append(sub3,ignore_index=False)
RFCD = RFCD.append(sub4,ignore_index=False)
RFCD = RFCD.append(sub4,ignore_index=False)

RFCD[RFCD["RFCD.Code"].isnull()]=0

piv = pd.pivot_table(RFCD,columns="RFCD.Code",index=RFCD.index,fill_value=0,dropna=False)
piv[piv.isnull()]=0
piv.index.name=None

#data = pd.concat([data,piv],axis=1)
data.drop(["RFCD.Code.1","RFCD.Percentage.1",
           "RFCD.Code.2","RFCD.Percentage.2",
           "RFCD.Code.3","RFCD.Percentage.3",
           "RFCD.Code.4","RFCD.Percentage.4",
           "RFCD.Code.5","RFCD.Percentage.5",],axis=1,inplace=True)

# %%
# Create dummies for SEO
sub1 = pd.DataFrame(data.ix[:,1:3])
sub1.rename(columns={"SEO.Code.1":"SEO.Code",
                     "SEO.Percentage.1":"SEO.Percentage"},inplace=True)

sub2 = pd.DataFrame(data.ix[:,3:5])
sub2.rename(columns={"SEO.Code.2":"SEO.Code",
                     "SEO.Percentage.2":"SEO.Percentage"},inplace=True)

sub3 = pd.DataFrame(data.ix[:,5:7])
sub3.rename(columns={"SEO.Code.3":"SEO.Code",
                     "SEO.Percentage.3":"SEO.Percentage"},inplace=True)

sub4 = pd.DataFrame(data.ix[:,7:9])
sub4.rename(columns={"SEO.Code.4":"SEO.Code",
                     "SEO.Percentage.4":"SEO.Percentage"},inplace=True)

sub5 = pd.DataFrame(data.ix[:,9:11])
sub5.rename(columns={"SEO.Code.5":"SEO.Code",
                     "SEO.Percentage.5":"SEO.Percentage"},inplace=True)

SEO = sub1.append(sub2,ignore_index=False)
SEO = SEO.append(sub3,ignore_index=False)
SEO = SEO.append(sub4,ignore_index=False)
SEO = SEO.append(sub4,ignore_index=False)

SEO[SEO["SEO.Code"].isnull()]=0

piv = pd.pivot_table(SEO,columns="SEO.Code",index=RFCD.index,fill_value=0,dropna=False)
piv[piv.isnull()]=0
piv.index.name=None

#data = pd.concat([data,piv],axis=1)
data.drop(["SEO.Code.1","SEO.Percentage.1",
           "SEO.Code.2","SEO.Percentage.2",
           "SEO.Code.3","SEO.Percentage.3",
           "SEO.Code.4","SEO.Percentage.4",
           "SEO.Code.5","SEO.Percentage.5",],axis=1,inplace=True)

# %%
from sklearn.preprocessing import LabelBinarizer

raw = pd.read_csv("data/unimelb_training.csv")

encoder = LabelBinarizer(neg_label=0, pos_label=1, sparse_output=False)
encoder.fit(['>10 to 15', '>5 to 10', '>=0 to 5', 'Less than 0', 'more than 15',
       'nan'])

people = pd.DataFrame()
for col in raw.columns:
    col_list = list(raw.columns) # list so I can use index later

    if col[:10] == 'Person.ID.':
        col_start = col_list.index(col)
        col_end = col_start + 15 # hard coded
        person = raw.iloc[:,col_start:col_end]

        # including our ID and status
        person.loc[:,'Grant.Application.ID'] = raw.loc[:,'Grant.Application.ID']
        person.loc[:,'Grant.Status'] = raw.loc[:,'Grant.Status']

        col_names = list(person.columns)
        col_names = [col.strip('0123456789') for col in col_names] # removes all numbers
        person.columns = col_names
        #print(len(person))

        # dealing with number of years at uni
        original = person.loc[:,'No..of.Years.in.Uni.at.Time.of.Grant.'].astype(str)
        transformed = encoder.transform(original)
        transformed = pd.DataFrame(transformed, columns=encoder.classes_)
        person.drop('No..of.Years.in.Uni.at.Time.of.Grant.', axis=1, inplace=True)
        person = pd.concat([person, transformed], axis=1)

        people = people.append(person, ignore_index=True)

# summaries for team
num_ppl = len(people) / len(person) # should be 15!
people.index = people.loc[:,'Grant.Application.ID']

num_ppl = people.groupby(['Grant.Application.ID'])['Person.ID.'].count() # include
total_birth_year = people.groupby(['Grant.Application.ID'])['Year.of.Birth.'].sum()
avg_birth_year = pd.Series(total_birth_year / num_ppl,name="Birth.Mean") # include
std_birth_year = pd.Series(people.groupby(['Grant.Application.ID'])['Year.of.Birth.'].std(),name="Birth.std")
std_birth_year[std_birth_year.isnull()]=0
min_birth_year = pd.Series(people.groupby(['Grant.Application.ID'])['Year.of.Birth.'].min(),name="Birth.min")
max_birth_year = pd.Series(people.groupby(['Grant.Application.ID'])['Year.of.Birth.'].max(),name="Birth.max")


num_successful = pd.Series(people.groupby(['Grant.Application.ID'])['Number.of.Successful.Grant.'].sum(),name="num_succ")
num_unsuccessful = pd.Series(people.groupby(['Grant.Application.ID'])['Number.of.Unsuccessful.Grant.'].sum(),name="num_unsucc")
ratio_successful = pd.Series(num_successful/(num_successful+num_unsuccessful),name="Ratio.Successful")
ratio_successful[ratio_successful.isnull()]=0

# number of phds - TODO could be improved
num_phd  = people.groupby(['Grant.Application.ID'])['With.PHD.'].count() # assuming only value ever entered is yes # include

# Number of persons per role type
roles = people["Role."].reset_index().pivot_table(columns="Role.",index=people.index,aggfunc=len,fill_value=0)
roles.fillna(value=0,inplace=True)
# Out:
# D:\Users\greg_\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (90,105,119,120,123,124,132,134,135,138,139,147,149,150,153,154,162,164,165,168,169,177,179,183,184,192,194,198,199,207,209,213,214,224,237,239,244) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
input = pd.concat([data,num_ppl],axis=1)
input = pd.concat([input,avg_birth_year],axis=1)
input = pd.concat([input,std_birth_year],axis=1)
input = pd.concat([input,min_birth_year],axis=1)
input = pd.concat([input,max_birth_year],axis=1)
input = pd.concat([input,ratio_successful],axis=1)
input = pd.concat([input,num_successful],axis=1)
#input = pd.concat([input,num_unsuccessful],axis=1)
input = pd.concat([input,num_phd],axis=1)
input = pd.concat([input,roles],axis=1)

input.columns.name = None

# %%
input.shape
# Out:
# (8708, 346)

# %%
#input.dropna(inplace=True)
input.fillna(value=0,inplace=True)
X = input.ix[:,1:]
y = input.ix[:,0]
X.shape
# Out:
# (8708, 345)

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=131078)

#rfc = RandomForestClassifier(n_jobs=-1,random_state=0)
#params={
#    "n_estimators":[8,10,12],
#    "min_samples_split":[2,4,6],
#    "min_samples_leaf":[1,2,4],
#}

#cv = GridSearchCV(rfc,param_grid=params,n_jobs=-1).fit(X_train,y_train)

gbc = GradientBoostingClassifier(random_state=0)
params={
    "n_estimators":[500],
    "min_samples_split":[6],
    "min_samples_leaf":[2],
}

cv = GridSearchCV(gbc,param_grid=params,n_jobs=-1).fit(X_train,y_train)


print(cv.best_params_)
print(cv.best_score_)
# Out:
# {'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 500}
# 0.871231696813

# %%
df = pd.DataFrame([X.columns,cv.best_estimator_.feature_importances_]).transpose()
df.columns=["name","score"]
df.sort(columns=["score"],ascending=False)[:20]
# Out:
# D:\Users\greg_\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#                                                 name      score
# 334                                 Ratio.Successful  0.0821857
# 312                                        Start.day  0.0669135
# 310                                       Start.year  0.0516281
# 311                                      Start.month   0.045512
# 297                                          Cat_10A  0.0446153
# 313                                      Contract_A   0.0330286
# 302                                          Cat_30B  0.0232134
# 316                                      Contract_D   0.0222213
# 319                                      Contract_G   0.0208375
# 314                                      Contract_B   0.0205413
# 315                                      Contract_C   0.0187346
# 335                                         num_succ  0.0183457
# 318                                      Contract_F   0.0177187
# 317                                      Contract_E   0.0174325
# 333                                        Birth.max  0.0169683
# 331                                        Birth.std  0.0162578
# 332                                        Birth.min  0.0160851
# 330                                       Birth.Mean  0.0160392
# 300                                          Cat_20C  0.0158559
# 344  (Grant.Application.ID, STUD_CHIEF_INVESTIGATOR)  0.0158359

# %%
y_pred =cv.predict(X_test)

# %%
accuracy = np.mean(y_pred == y_test)
accuracy
# Out:
# 0.88059701492537312

# %%
from sklearn.metrics import confusion_matrix
conmat = np.array(confusion_matrix(y_test, y_pred))
confusion = pd.DataFrame(conmat, index=['not_granted', 'granted'],columns=['predicted_not_granted', 'predicted_granted'])
confusion
# Out:
#              predicted_not_granted  predicted_granted
# not_granted                    843                102
# granted                        106                691

# %%
from sklearn.metrics import classification_report
cls_rep = classification_report(y_test, y_pred)
print(cls_rep)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.89      0.89      0.89       945
#           1       0.87      0.87      0.87       797
#
# avg / total       0.88      0.88      0.88      1742

# %%
for i,n in enumerate(input):
    print(i,n)
# Out:
# 0 Grant.Status
# 1 Sponsor_100D
# 2 Sponsor_101A
# 3 Sponsor_103C
# 4 Sponsor_105A
# 5 Sponsor_107C
# 6 Sponsor_10B
# 7 Sponsor_111C
# 8 Sponsor_112D
# 9 Sponsor_113A
# 10 Sponsor_118B
# 11 Sponsor_11C
# 12 Sponsor_120D
# 13 Sponsor_126B
# 14 Sponsor_128D
# 15 Sponsor_12D
# 16 Sponsor_130B
# 17 Sponsor_132D
# 18 Sponsor_133A
# 19 Sponsor_134B
# 20 Sponsor_135C
# 21 Sponsor_136D
# 22 Sponsor_137A
# 23 Sponsor_138B
# 24 Sponsor_139C
# 25 Sponsor_13A
# 26 Sponsor_140D
# 27 Sponsor_141A
# 28 Sponsor_142B
# 29 Sponsor_143C
# 30 Sponsor_144D
# 31 Sponsor_145A
# 32 Sponsor_146B
# 33 Sponsor_147C
# 34 Sponsor_148D
# 35 Sponsor_149A
# 36 Sponsor_14B
# 37 Sponsor_150B
# 38 Sponsor_151C
# 39 Sponsor_152D
# 40 Sponsor_153A
# 41 Sponsor_154B
# 42 Sponsor_155C
# 43 Sponsor_156D
# 44 Sponsor_157A
# 45 Sponsor_158B
# 46 Sponsor_159C
# 47 Sponsor_15C
# 48 Sponsor_160D
# 49 Sponsor_161A
# 50 Sponsor_162B
# 51 Sponsor_163C
# 52 Sponsor_164D
# 53 Sponsor_165A
# 54 Sponsor_166B
# 55 Sponsor_167C
# 56 Sponsor_168D
# 57 Sponsor_169A
# 58 Sponsor_16D
# 59 Sponsor_170B
# 60 Sponsor_171C
# 61 Sponsor_172D
# 62 Sponsor_173A
# 63 Sponsor_174B
# 64 Sponsor_175C
# 65 Sponsor_176D
# 66 Sponsor_177A
# 67 Sponsor_178B
# 68 Sponsor_179C
# 69 Sponsor_180D
# 70 Sponsor_182B
# 71 Sponsor_183C
# 72 Sponsor_184D
# 73 Sponsor_185A
# 74 Sponsor_186B
# 75 Sponsor_187C
# 76 Sponsor_188D
# 77 Sponsor_189A
# 78 Sponsor_18B
# 79 Sponsor_190B
# 80 Sponsor_191C
# 81 Sponsor_192D
# 82 Sponsor_193A
# 83 Sponsor_194B
# 84 Sponsor_195C
# 85 Sponsor_196D
# 86 Sponsor_197A
# 87 Sponsor_198B
# 88 Sponsor_199C
# 89 Sponsor_1A
# 90 Sponsor_200D
# 91 Sponsor_201A
# 92 Sponsor_202B
# 93 Sponsor_203C
# 94 Sponsor_204D
# 95 Sponsor_205A
# 96 Sponsor_206B
# 97 Sponsor_207C
# 98 Sponsor_208D
# 99 Sponsor_20D
# 100 Sponsor_210B
# 101 Sponsor_211C
# 102 Sponsor_212D
# 103 Sponsor_213A
# 104 Sponsor_214B
# 105 Sponsor_215C
# 106 Sponsor_216D
# 107 Sponsor_217A
# 108 Sponsor_218B
# 109 Sponsor_219C
# 110 Sponsor_21A
# 111 Sponsor_220D
# 112 Sponsor_221A
# 113 Sponsor_222B
# 114 Sponsor_223C
# 115 Sponsor_224D
# 116 Sponsor_225A
# 117 Sponsor_226B
# 118 Sponsor_227C
# 119 Sponsor_228D
# 120 Sponsor_229A
# 121 Sponsor_230B
# 122 Sponsor_232D
# 123 Sponsor_233A
# 124 Sponsor_234B
# 125 Sponsor_235C
# 126 Sponsor_237A
# 127 Sponsor_238B
# 128 Sponsor_239C
# 129 Sponsor_23C
# 130 Sponsor_240D
# 131 Sponsor_241A
# 132 Sponsor_242B
# 133 Sponsor_243C
# 134 Sponsor_244D
# 135 Sponsor_245A
# 136 Sponsor_246B
# 137 Sponsor_247C
# 138 Sponsor_24D
# 139 Sponsor_250B
# 140 Sponsor_251C
# 141 Sponsor_252D
# 142 Sponsor_253A
# 143 Sponsor_255C
# 144 Sponsor_256D
# 145 Sponsor_257A
# 146 Sponsor_258B
# 147 Sponsor_259C
# 148 Sponsor_260D
# 149 Sponsor_261A
# 150 Sponsor_262B
# 151 Sponsor_263C
# 152 Sponsor_265A
# 153 Sponsor_266B
# 154 Sponsor_267C
# 155 Sponsor_268D
# 156 Sponsor_269A
# 157 Sponsor_26B
# 158 Sponsor_270B
# 159 Sponsor_271C
# 160 Sponsor_272D
# 161 Sponsor_273A
# 162 Sponsor_274B
# 163 Sponsor_275C
# 164 Sponsor_276D
# 165 Sponsor_277A
# 166 Sponsor_278B
# 167 Sponsor_279C
# 168 Sponsor_27C
# 169 Sponsor_280D
# 170 Sponsor_281A
# 171 Sponsor_282B
# 172 Sponsor_284D
# 173 Sponsor_285A
# 174 Sponsor_286B
# 175 Sponsor_287C
# 176 Sponsor_288D
# 177 Sponsor_289A
# 178 Sponsor_28D
# 179 Sponsor_290B
# 180 Sponsor_292D
# 181 Sponsor_294B
# 182 Sponsor_295C
# 183 Sponsor_296D
# 184 Sponsor_297A
# 185 Sponsor_298B
# 186 Sponsor_299C
# 187 Sponsor_29A
# 188 Sponsor_2B
# 189 Sponsor_300D
# 190 Sponsor_302B
# 191 Sponsor_303C
# 192 Sponsor_304D
# 193 Sponsor_305A
# 194 Sponsor_307C
# 195 Sponsor_308D
# 196 Sponsor_309A
# 197 Sponsor_310B
# 198 Sponsor_311C
# 199 Sponsor_312D
# 200 Sponsor_313A
# 201 Sponsor_314B
# 202 Sponsor_315C
# 203 Sponsor_316D
# 204 Sponsor_317A
# 205 Sponsor_318B
# 206 Sponsor_319C
# 207 Sponsor_323C
# 208 Sponsor_324D
# 209 Sponsor_325A
# 210 Sponsor_326B
# 211 Sponsor_328D
# 212 Sponsor_329A
# 213 Sponsor_32D
# 214 Sponsor_330B
# 215 Sponsor_331C
# 216 Sponsor_334B
# 217 Sponsor_339C
# 218 Sponsor_33A
# 219 Sponsor_342B
# 220 Sponsor_346B
# 221 Sponsor_347C
# 222 Sponsor_349A
# 223 Sponsor_34B
# 224 Sponsor_357A
# 225 Sponsor_362B
# 226 Sponsor_363C
# 227 Sponsor_36D
# 228 Sponsor_370B
# 229 Sponsor_371C
# 230 Sponsor_372D
# 231 Sponsor_373A
# 232 Sponsor_374B
# 233 Sponsor_37A
# 234 Sponsor_38B
# 235 Sponsor_39C
# 236 Sponsor_3C
# 237 Sponsor_40D
# 238 Sponsor_415C
# 239 Sponsor_41A
# 240 Sponsor_427C
# 241 Sponsor_428D
# 242 Sponsor_429A
# 243 Sponsor_42B
# 244 Sponsor_430B
# 245 Sponsor_431C
# 246 Sponsor_432D
# 247 Sponsor_433A
# 248 Sponsor_434B
# 249 Sponsor_435C
# 250 Sponsor_436D
# 251 Sponsor_437A
# 252 Sponsor_44D
# 253 Sponsor_47C
# 254 Sponsor_48D
# 255 Sponsor_49A
# 256 Sponsor_4D
# 257 Sponsor_51C
# 258 Sponsor_52D
# 259 Sponsor_53A
# 260 Sponsor_54B
# 261 Sponsor_55C
# 262 Sponsor_56D
# 263 Sponsor_58B
# 264 Sponsor_59C
# 265 Sponsor_5A
# 266 Sponsor_60D
# 267 Sponsor_62B
# 268 Sponsor_63C
# 269 Sponsor_65A
# 270 Sponsor_66B
# 271 Sponsor_67C
# 272 Sponsor_68D
# 273 Sponsor_69A
# 274 Sponsor_6B
# 275 Sponsor_72D
# 276 Sponsor_73A
# 277 Sponsor_74B
# 278 Sponsor_75C
# 279 Sponsor_77A
# 280 Sponsor_78B
# 281 Sponsor_7C
# 282 Sponsor_80D
# 283 Sponsor_81A
# 284 Sponsor_82B
# 285 Sponsor_83C
# 286 Sponsor_84D
# 287 Sponsor_85A
# 288 Sponsor_86B
# 289 Sponsor_87C
# 290 Sponsor_89A
# 291 Sponsor_90B
# 292 Sponsor_91C
# 293 Sponsor_93A
# 294 Sponsor_94B
# 295 Sponsor_95C
# 296 Sponsor_97A
# 297 Sponsor_9A
# 298 Cat_10A
# 299 Cat_10B
# 300 Cat_20A
# 301 Cat_20C
# 302 Cat_30A
# 303 Cat_30B
# 304 Cat_30C
# 305 Cat_30D
# 306 Cat_30E
# 307 Cat_30F
# 308 Cat_30G
# 309 Cat_40C
# 310 Cat_50A
# 311 Start.year
# 312 Start.month
# 313 Start.day
# 314 Contract_A
# 315 Contract_B
# 316 Contract_C
# 317 Contract_D
# 318 Contract_E
# 319 Contract_F
# 320 Contract_G
# 321 Contract_H
# 322 Contract_I
# 323 Contract_J
# 324 Contract_K
# 325 Contract_L
# 326 Contract_M
# 327 Contract_O
# 328 Contract_P
# 329 Contract_Q
# 330 Person.ID.
# 331 Birth.Mean
# 332 Birth.std
# 333 Birth.min
# 334 Birth.max
# 335 Ratio.Successful
# 336 num_succ
# 337 With.PHD.
# 338 ('Grant.Application.ID', 'CHIEF_INVESTIGATOR')
# 339 ('Grant.Application.ID', 'DELEGATED_RESEARCHER')
# 340 ('Grant.Application.ID', 'EXTERNAL_ADVISOR')
# 341 ('Grant.Application.ID', 'EXT_CHIEF_INVESTIGATOR')
# 342 ('Grant.Application.ID', 'HONVISIT')
# 343 ('Grant.Application.ID', 'PRINCIPAL_SUPERVISOR')
# 344 ('Grant.Application.ID', 'STUDRES')
# 345 ('Grant.Application.ID', 'STUD_CHIEF_INVESTIGATOR')
